# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dat = pd.read_pickle('allDat.pkl')

# %%
dat.columns.values
# Out:
# array(['Kundenname', 'Kundenname Zeile 2 ', 'Adresse', 'Adresse Zeile 2',
#        'Kundennation', 'PLZ', 'Stadt', 'Bundesland', 'Telefon', 'E-Mail ',
#        'Personen', 'Newsletter ja/nein', 'Brand', 'Hausnummer',
#        'Produkttyp', 'Haustier ja/nein', 'Hausnation', 'Hausgebiet',
#        'Preistyp', 'Endreinigung ja/nein', 'Versicherung ja/nein',
#        'Saison', 'Buchungsnummer', 'Währung', 'Mietpreis',
#        'Buchungsdatum', 'Buchung: direkt/indirekt', 'Verkaufskanal',
#        'Anreise', 'Abreise', 'Zahlungsart', 'Name1', 'Name2', 'Name3',
#        'time_btw_book_travel_days'], dtype=object)

# %%
dat['Buchungsdatum'].hist(bins=50)

# %%
dat['Anreise'].hist(bins=50)

# %%
dat['time_btw_book_travel_days'].hist(bins=40)
